# %% [markdown]
# <a href="https://colab.research.google.com/github/pallamadhavi/madhaviMasterThesis/blob/main/untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evaluation Queries
#    *    **We have desinged 10 Questions which covers theory coding and database
# creation tasks in pattern mining.**
#    *    **We have designed them in 3 different prompt paradigms:**
#           1.     Zeroshot prompts
#           2.     One/Single shot  prompts
#           3.     Fewshot prompts
#
# ---
# # **Zero-shot Queries**
#
# ### **Theory-Based Questions**
#
# 1. **Question:** What does minRF represent in coverage pattern mining?
#
# 2. **Question:** Explain about utility pattern mining and give me a sample of utility transactional database and its format?
#
# ---
# ### **Coding & Implementation Questions**
#
# 3. **Question:** Which parameter in the FP-Growth constructor allows you to control the input field separator and how is it set?
#
# 4. **Question:** What is the exact import path for the FPGrowth algorithm in PAMI, and how do you instantiate it?
#
# 5. **Question:** Give me the code for RSFPGrowth algorithm using PAMI?
#
# 6. **Question:** How can you run the recurring Pattern RPGrowth algorithm in the terminal using PAMI?
#
# ---
# ### **Dataset Tasks**
#
# 7. **Question:** How can I generate a synthetic sequential database with 1000 sequences using PAMI and save it as a CSV file?
#
# 8. **Question:** Convert the data frame into a multiple time series database?
#
# 9. **Question:** Generate synthetic transactional DB with 19987 transactions with item range 1-999, items per transaction = 5-15, save as new_synth.txt?
#
# 10. **Question:** Generate a synthetic transactional dataset where:   Each transaction consists of **a unique Transaction ID** (a randomly generated number between 1 and 99999), The **Transaction column** contains a list of item IDs (random integers between 1 and 999), Each transaction should have **5 to 15 items**, separated by tab (`\t`), The output should be in **tab-separated format** where the first column is the Transaction ID, and the second column is the list of item IDs, Ensure the number of transactions is **19987** (matching the dataset size).
# Ensure the highest item number is **999**, the lowest is **1**, The dataset must have an **average transaction size of ~0.55**, Do not include duplicate item IDs within a single transaction and finally give me the transactional dataset by following all the requirements.
# ---

# %% [markdown]
# # **Single-shot Queries**
#
# ### **Theory Questions**
#
# 1. **Example Q/A:**
#    - Q: What does minSup mean in the Apriori algorithm from PAMI?
#    - A: minSup is the minimum number of transactions a pattern must appear in to be considered frequent.
#    - **Target Question:** What does minRF represent in coverage pattern mining?
#
# 2. **Example Q/A:**
#    - Q: What does a utility transactional database contain?
#    - A: A utility transactional database consists of transactions with items and their corresponding utility values. Each item’s utility is the product of its internal (quantity) and external (unit price) values.
#    - **Target Question:** Explain about utility pattern mining and give me a sample of utility transactional database and its format.
# ---
#
# ### **Coding Questions**
#
# 3. **Example Q/A:**
#    - Q: Which parameter controls minimum support in FP-Growth?
#    - A: The minSup parameter defines the minimum support threshold in the FP-Growth constructor and can be specified as an integer, float, or string.
#    - **Target Question:** Which parameter in the FP-Growth constructor allows you to control the input field separator and how is it set?
#
#
# 4. **Example Q/A:**
#    - Q: How to import Apriori algorithm in PAMI?
#    - A: `import PAMI.frequentPattern.basic.Apriori as alg`
#    - **Target Question:** What is the exact import path for the FP-Growth algorithm in PAMI, and how do you instantiate it?
#
# 5. **Example Q/A:**
#   - Q: How do you run the FPgrowth algorithm in PAMI?
#    ```python
#    from PAMI.frequentPattern.basic import FPGrowth as alg
#  iFile = 'sampleDB.txt'
#  minSup = 10 # can also be specified between 0 and 1
#  obj = alg.FPGrowth(iFile, minSup)
#  obj.mine()
#  frequentPatterns = obj.getPatterns()
#  print("Total number of Frequent Patterns:", len(frequentPatterns))
#  obj.save(oFile)
#  Df = obj.getPatternInDataFrame()
#  memUSS = obj.getMemoryUSS()
#  print("Total Memory in USS:", memUSS)
#  memRSS = obj.getMemoryRSS()
#  print("Total Memory in RSS", memRSS)
#  run = obj.getRuntime()
#  print("Total ExecutionTime in seconds:", run)
#    ```
#    - **Target Question:** Give me the code for RSFPGrowth algorithm using PAMI?
#
# 6. **Example Q/A:**
#   - Q How can we run Apriori with a tab-separated file and minimum support of 10 using PAMI Library in terminal?
#    ```bash
#    python3 Apriori.py Transactional_dataset.txt 10 "\t"
#    ```
#    - **Target Question:** How can we run the RPGrowth algorithm with a tab separated file using PAMI Library in terminal?
# ---
#
# ### **Dataset Tasks**
#
# 7. **Example Q/A:**
#   - Q Create a synthetic Sequential database using the below code.
#    ```python
#    from PAMI.extras.syntheticDataGenerator import SequentialDatabase as db
#
# obj = db.SequentialDatabase(databaseSize=1000,             # Number of sequences
#     avgPatternsPerSequence=4,      # Average patterns per sequence
#     avgItemsPerPatterns=5,         # Average items per pattern
#     numItems=50 )
# obj.create()
# obj.save('sequentialDatabase.csv')
#    ```
#    - **Task:** Create the sequential database and save it as Sequential1Database.csv` and get the sequence.
#
# 8. **Example Q/A:**
#    - Q Converting the data frame into a transactional database
#
#    ```python
#    from PAMI.extras.convert import denseDF2DB
#    obj.convert2TransactionalDatabase('output.csv', '>=', 35)
#    ```
#    - **Task:** Convert the data frame into a multiple time series database according to PAMI Library?
#
#
# 9. **Example Q/A:**
#   - Q How do you create synthetic transactions using PAMI?
#
#    ```python
#    from PAMI.extras.syntheticDataGenerator import TransactionalDatabase as db
# obj = db.generate(1000, 5, 15, 1, 999, "\t")
# obj.save("syn_db.txt")
#    ```
#    - **Task:** Generate synthetic transactional DB with 19987 transactions, item range 1–999, items per transaction = 5–15, save as new_synth.txt and print it.
#
# 10. **Format Example:**
#     ```
#     17203 25\t163\t190\t581\t782\t890\t898
#     ```
#     - **Task:** Generate a synthetic transactional dataset where: Each transaction consists of a unique Transaction ID (a randomly generated number between 1 and 99999), the Transaction column contains a list of item IDs (random integers between 1 and 999), each transaction should have 5 to 15 items, separated by tab (\t). Ensure the number of transactions is 19987. Do not include duplicate item IDs within a single transaction. Format output exactly as shown.
# ---

# %% [markdown]
# # **Few-shot Evaluation Queries**
#
# ### **Theory-Based Questions**
# ### 1. Coverage Pattern Mining Concept
# **Example 1:**
# **Question:** What does minSup mean in the Apriori algorithm from PAMI?
# **Answer:** minSup is the minimum number of transactions a pattern must appear in to be considered frequent.
#
# **Example 2:**
# **Question:** What does minConf represent in association rule generation in PAMI?
# **Answer:** minConf sets the threshold for rule confidence, filtering out weak rules with low predictive strength.
#
# **Target Question:**
# What does minRF represent in coverage pattern mining?
#
# ---
#
# ### 2. Utility Pattern Mining Explanation
# **Example 1:**
# **Question:** What is high utility pattern mining in PAMI?
# **Answer:** High utility pattern mining discovers itemsets that have high utility values (e.g., profit), not just high frequency.
#
# **Example 2:**
# **Question:** What is the utility of an item in a transaction?
# **Answer:** It is calculated by multiplying the item's quantity (internal utility) with its price (external utility).
#
# **Target Question:**
# Explain about utility pattern mining and give me a sample of utility transactional database and its format.
#
# ---
# ### **Coding & Implementation Questions**
# ### 3. FP-Growth Parameters
# **Example 1:**
# **Question:** What is the use of the minSup parameter in FP-Growth?
# **Answer:** The minSup parameter specifies the minimum number or proportion of transactions required for a pattern to be considered frequent.
#
# **Example 2:**
# **Question:** How does the oFile parameter function in FP-Growth?
# **Answer:** The oFile parameter defines the output file where the resulting frequent patterns will be saved after mining.
#
# **Target Question:**
# Which parameter in the FP-Growth constructor allows you to control the input field separator and how is it set?
#
# ---
#
# ### 4. Algorithm Import Paths
# **Example 1:**
# **Question:** How do you import the UPGrowth algorithm?
# **Answer:** `from PAMI.highUtilityPattern.basic import UPGrowth as alg` and instantiate using `alg.UPGrowth(iFile, minUtil)`.
#
# **Example 2:**
# **Question:** What is the import path for RPGrowth?
# **Answer:** `from PAMI.recurringPattern.basic import RPGrowth as alg`.
#
# **Target Question:**
# What is the exact import path for the FP-Growth algorithm in PAMI, and how do you instantiate it?
#
# ---
#
# ### 5. Algorithm Implementation Code
# **Example 1: FPGrowth Implementation**
# ```python
# from PAMI.frequentPattern.basic import FPGrowth as alg
# iFile = 'sampleDB.txt'
# minSup = 10  # can also be specified between 0 and 1
# obj = alg.FPGrowth(iFile, minSup)
# obj.mine()
# frequentPatterns = obj.getPatterns()
# print("Total number of Frequent Patterns:", len(frequentPatterns))
# obj.save(oFile)
# Df = obj.getPatternInDataFrame()
# memUSS = obj.getMemoryUSS()
# print("Total Memory in USS:", memUSS)
# memRSS = obj.getMemoryRSS()
# print("Total Memory in RSS", memRSS)
# run = obj.getRuntime()
# print("Total ExecutionTime in seconds:", run)
# ```
#
# **Example 2: HUFIM Implementation**
# ```python
# from PAMI.highUtilityFrequentPattern.basic import HUFIM as alg
# obj = alg.HUFIM("input.txt", 35, 20)
# obj.mine()
# Patterns = obj.getPatterns()
# obj.save("output")
# print("Total number of high utility frequent Patterns:", len(Patterns))
# memUSS = obj.getMemoryUSS()
# print("Total Memory in USS:", memUSS)
# memRSS = obj.getMemoryRSS()
# print("Total Memory in RSS", memRSS)
# run = obj.getRuntime()
# print("Total ExecutionTime in seconds:", run)
# ```
#
# **Task:**
# Write Python code to run RSFPGrowth with `sampleDB.txt`, `minRS = 15`, tab separator, and save to `RSFP_results.txt`.
#
# ---
#
# ### 6. Terminal Command Execution
# **Example for Apriori:**
# How to run Apriori algorithm with a tab-separated file and minimum support of 10 in terminal?
# ```bash
# python3 Apriori.py Transactional_dataset.txt 10 "\t"
# ```
#  How to run UPGrowth algorithm with a tab-separated file and minimum support of 35 in terminal?
#
# **Example for UPGrowth:**
# ```bash
# python3 UPGrowth.py sampleTDB.txt output.txt sampleN.txt 35 "\t"
# ```
#
# **Task:**
# How can you run the recurring Pattern(RPGrowth) algorithm in the terminal using PAMI in terminal?
#
#
# ---
# ### **Dataset Tasks**
# ### 7. Sequential Database Creation
# **Example 1: Database Generation**
# Create a synthetic Sequential database using the below code
#
# ```python
# from PAMI.extras.syntheticDataGenerator import SequentialDatabase as db
#
# obj = db.SequentialDatabase(
#     databaseSize=1000,              # Number of sequences
#     avgItemsPerPatterns=5,          # Average items per pattern
#     avgPatternsPerSequence=4,       # Average patterns per sequence
#     numItems=50,)
# obj.create()
# obj.save('sequentialDatabase.csv')
# ```
#
# **Example 2: Sequence Retrieval**
# ```python
# Sequence = obj.getSequence()
# ```
#
# **Task:**
# Create the sequential database and save it as `Sequential1Database.csv` and print it.
#
# ---
#
# ### 8. Database Conversion
# **Example 1: Transactional Conversion**
# Converting the data frame into a transactional database
#
#
# ```python
# from PAMI.extras.convert import denseDF2DB as db
# obj = db.denseDF2DB(dataset)
# obj.convert2TransactionalDatabase('PM24TrasactionalHeavyPollutionRecordingSensors.csv', '>=', 35)
# !head -1 'PM24TrasactionalHeavyPollutionRecordingSensors.csv'
# ```
#
# **Example 2: Temporal Conversion**
# Converting the data frame into a temporal database
# ```python
# from PAMI.extras.convert import denseDF2DB as db
# obj = db.denseDF2DB(dataset)
# obj.convert2TemporalDatabase('PM24TemporalHeavyPollutionRecordingSensors.csv', '>=', 35)
# !head -1 'PM24TemporalHeavyPollutionRecordingSensors.csv'
# ```
#
# **Task:**
# Convert the data frame into a multiple time series database.
#
# ---
#
# ### 9. Transactional Database Generation
# **Example 1: Synthetic Generation**
# Generate synthetic transactional DB
# ```python
# from PAMI.extras.syntheticDataGenerator import syntheticTransactionDB
# obj = syntheticTransactionDB.generate(1000, 5, 15, 1, 999, "\t")
# obj.save("syn_db.txt")
# ```
#
# **Example 2: Sample Display**
# Print first 3 transactions
#
# ```python
# with open("syn_db.txt") as f:
#     for _ in range(3): print(f.readline())
# ```
#
# **Task:**
# Generate 19987 transactions with item range 1-999, items per transaction = 5-15, save as `new_synth.txt` and print it.
#
# ---
#
# ### 10. Complex Transactional Dataset
# *Question:**
# Generate a synthetic transactional dataset where: Each transaction consists of a unique Transaction ID (a randomly generated number between 1 and 99999), the Transaction column contains a list of item IDs (random integers between 1 and 999), each transaction should have 5 to 15 items, separated by tab (`\t`). Ensure the number of transactions is 19987. Do not include duplicate item IDs within a single transaction. Format output exactly as shown.
#
# **Few Examples:**
# ```
# 17203 25\t163\t190\t581\t782\t890\t898
# 32044 52\t185\t239\t486\t510\t538\t571\t612\t623
# 3594 151\t275\t322\t343\t620\t803
# 27252 12\t256\t318\t334\t413\t538\t645\t694\t763
# 78762 154\t328\t346\t373\t377\t424\t494\t789\t862
# ```
#
# **Task:**
# Generate the transactional database file meeting all specifications.
